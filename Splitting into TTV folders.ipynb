# %%
import pandas as pd
import os
import shutil

# %%
df_train = pd.read_csv("train.csv")

# %%
# Source directory containing images
source_directory = 'C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/images_new'

# Destination directory to copy images into
destination_directory = 'C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs'
if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

# Function to copy images based on file names
def copy_images(row):
    file_name = str(row['imdbId'])+".jpg"
    source_path = os.path.join(source_directory, file_name)
    destination_path = os.path.join(destination_directory, file_name)
    shutil.copy(source_path, destination_path)
    print(f"Copied {file_name} to {destination_directory}")

# Copy images
df_train.apply(copy_images, axis=1)
# Out:
# Copied 286218.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs
# Copied 91860.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs
# Copied 156849.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs
# Copied 209322.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs
# Copied 120879.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs
# Copied 70034.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs
# Copied 65207.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs
# Copied 93091.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs
# Copied 114571.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs
# Copied 301429.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs
# Copied 92214.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/train_imgs
# ...

# %%
df_test = pd.read_csv("test.csv")

# %%
# Source directory containing images
source_directory = 'C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/images_new'

# Destination directory to copy images into
destination_directory = 'C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs'
if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

# Function to copy images based on file names
def copy_images(row):
    file_name = str(row['imdbId'])+".jpg"
    source_path = os.path.join(source_directory, file_name)
    destination_path = os.path.join(destination_directory, file_name)
    shutil.copy(source_path, destination_path)
    print(f"Copied {file_name} to {destination_directory}")

# Copy images
df_test.apply(copy_images, axis=1)
# Out:
# Copied 87015.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs
# Copied 95882.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs
# Copied 29855.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs
# Copied 373175.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs
# Copied 57495.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs
# Copied 91578.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs
# Copied 122143.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs
# Copied 103767.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs
# Copied 120797.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs
# Copied 77147.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs
# Copied 93137.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/test_imgs
# ...

# %%
df_val = pd.read_csv("val.csv")

# %%
# Source directory containing images
source_directory = 'C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/images_new'

# Destination directory to copy images into
destination_directory = 'C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs'
if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

# Function to copy images based on file names
def copy_images(row):
    file_name = str(row['imdbId'])+".jpg"
    source_path = os.path.join(source_directory, file_name)
    destination_path = os.path.join(destination_directory, file_name)
    shutil.copy(source_path, destination_path)
    print(f"Copied {file_name} to {destination_directory}")

# Copy images
df_val.apply(copy_images, axis=1)
# Out:
# Copied 103747.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs
# Copied 104545.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs
# Copied 97428.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs
# Copied 70903.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs
# Copied 51808.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs
# Copied 109001.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs
# Copied 82288.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs
# Copied 378284.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs
# Copied 181984.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs
# Copied 332047.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs
# Copied 267248.jpg to C:/Users/Hp/Desktop/IIT Research Docs/Movie Labeling/val_imgs
# ...
